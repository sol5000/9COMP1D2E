# %% [markdown]
# Variables are unique names you assign to specify data stored in memory
# <div><img src=attachment:9a36d07c-37cd-4221-b291-0bc99b263930.png width = 400></div>

# %%
name = "John"
age = 13
print(name + " is " + str(age) + " years old")

#What are the variables in the snippit above?
answer1 = "name age"
# Out:
# John is 13 years old

# %% [markdown]
# Variables can change value during the program operation

# %%
#one year passes...
age = age + 1
print(name + " is now " + str(age) + " years old")

#in your own words, what does 'age = age + 1' do?
answer2 = "add one to the variable age"
# Out:
# John is now 14 years old

# %% [markdown]
# There are different types of variables, including:
# <br><br>    int - integers: whole numbers
# <br>    float - floating point numbers: decimal numbers
# <br>    str - String: words, letters, sentences, and whole paragraphs

# %%
height = 167.5

print(name + " is " + str(height) + " meters tall")

#which variable is an int?
answer3 = "age"

#which variable is a str?
answer4 = "name"

#which variable is a float?
answer5 = "height"
# Out:
# John is 167.5 meters tall

# %% [markdown]
# In Python, you can give a variable almost any name, but the style convention is to use lower case words seperated by _.

# %%
type_of_bus = "electric"
lengthOfBus = 15.3 #meters
passenger = 40
Passenger = "Alice"

#Which of these variable names match the style convention for Python?
answer6 = "type_of_bus, passenger"

# %% [markdown]
# Did you notice there were two variables with very similar names: passenger and Passenger?

# %%
#What do you think this snippet of code will do?
answer7 = "alice is the 40th person on the bus"

print(Passenger + " is the " + str(passenger) + "th person on the bus")
# Out:
# Alice is the 40th person on the bus

# %% [markdown]
# There are a lot of ways that variables can get their values - it doesn't have to be hardcoded by you, the programmer<br><br>In this example, you will be the user and can supply your own data

# %%
user_name = await input("What is your name?")
# Out:
# What is your name? hollen

# %%
print(name + ", I'd like you to meet " + user_name)
# Out:
# John, I'd like you to meet hollen

# %% [markdown]
# Values for your variables can be: <br>
# <br> - Hardcoded by the programmer
# <br> - Supplied by your user
# <br> - Read from a file
# <br> - Retrieved from a database
# <br> - Fetched from a website/server/network
# <br> - Measured by a devices (ie, a temperature reading)
# <br> - Randomly generated

# %% [markdown]
# When you are done, run the code snippit below and show your teacher.

# %%
print("The variables in snippit [2] are: " + answer1)
print("age = age + 1 #" + answer2)
print(answer3 + " is an int")
print(answer4 + " is a str")
print(answer5 + " is a float")
print(answer6 + " is/are variable names that match the python style guidelines")
print(answer7)
print("My name is " + user_name)
# Out:
# The variables in snippit [2] are: name age
# age = age + 1 #add one to the variable age
# age is an int
# name is a str
# height is a float
# type_of_bus, passenger is/are variable names that match the python style guidelines
# alice is the 40th person on the bus
# My name is hollen

# %% [markdown]
# Was that too easy? Use the space below and the Python <a href scr= https://www.oreilly.com/library/view/learning-jupyter/9781785884870/ch02s05.html> random library </a> to write a python sippet you can use to play Rock Paper Scissors. The user should be able to choose rock, paper, or scissors while the computer oponent should randomly choose as well. The snippit should determine the winner of the match

# %%
import random
user = await input()
print("you chose " + user)
computer = random.choice(['rock', 'paper', 'scissors'])
print("computer chose " + computer)
if user == computer:
    print("tie")
elif user == 'rock' and computer == 'scissors':
    print("you win")
elif user == 'paper' and computer == 'rock':
    print("you win")
elif user == 'scissors' and computer == 'paper':
    print("you win")
else: 
    print("you lose")
