# %% [markdown]
# This is a text area. Below is a code area. You can try running the sample code below by clicking first on the code block itself, then the run button.
#
# <div><img src=attachment:e6dd41b4-9f2e-4c34-9e8f-77a4aa733794.png width = 400></div>
#
# Try it now!

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# You can also adjust any of these code blocks yourself. Try adding your name inside the " marks below, and running the python snippit

# %%
name = "hollen" #put your name between the " marks
print("Hi, " + name + ", nice to meet you!")
# Out:
# Hi, hollen, nice to meet you!

# %% [markdown]
# You can save your work with the save icon:
# <div><img src=attachment:8ce030be-0297-4001-a92a-9ffb9b594494.png width = 400></div>
# Go ahead and try. Save, then refresh this page. See if your name persists

# %% [markdown]
# Cool. But. Where is your work saved? It's actually hidden away in your browser's cache. That's no good. You're going to lose your work if you change/update/clear your browser. Let's archive your hard work on your local hard drive. Right click on this notebook in the file browser to the left, then download it
#
# <div><img src=attachment:6dd302f4-4571-426b-b404-0bcc85e238f0.png width = 400></div>
#
# Save your notebook as a .ipynb file somewhere that you will be able to find it later. I've added mine to my FirstStepsInPython Folder in my Documents
#
# <div><img src=attachment:b10ac909-6359-420d-8128-2bf1d416543d.png width = 400></div>

# %% [markdown]
# You should save your work to your local hard drive this way at the end of each lesson.

# %% [markdown]
# You've reached the end of this notebook. Run the code snippit below and show your teacher:

# %%
if name == "":
    print("Go back to step [5], enter your name, and run the code snippit")
else:
    print(name + " has completed the introduction!")
# Out:
# hollen has completed the introduction!
